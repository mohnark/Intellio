# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re

path = 'sample_ds/'

# %%
df_universities = pd.read_csv(path + 'unis.csv')
df_jobs = pd.read_csv(path + 'jobs.csv')

# %%
def clean_structure(text):
    text = re.sub(r'\\\'', "'", text)
    text = re.sub(r'\\\"', '"', text)
    text = re.sub(r'\d+\scredit\(s\)', '', text)  
    text = re.sub(r':', ' ', text) 
    text = re.sub(r'\s+', ' ', text) 
    text = text.lower()  
    return text.strip()


def clean_structure_field(text):
    text = text.strip('[]').split(',')
    return ' '.join([clean_structure(course) for course in text])

# %%
# Clean Dataframe
df_universities['structure'] = df_universities['structure'].fillna('')
df_universities['structure'] = df_universities['structure'].apply(lambda x: clean_structure_field(x) if x else '')
df_jobs['skills'] = df_jobs['skills'].fillna('')

# %%
job_responsibilities = df_jobs['skills']
university_structures =  df_universities['structure']

# %%
# Use Model to Identify Similarities
vectorizer = TfidfVectorizer(stop_words='english')

tfidf_matrix_jobs = vectorizer.fit_transform(job_responsibilities)
tfidf_matrix_universities = vectorizer.transform(university_structures)

similarity_matrix = cosine_similarity(tfidf_matrix_jobs, tfidf_matrix_universities)

def match_jobs_to_universities(similarity_matrix, df_jobs, df_universities):
    matched_universities = []
    for i in range(similarity_matrix.shape[0]):
        most_similar_index = np.argmax(similarity_matrix[i])
        matched_universities.append(df_universities.iloc[most_similar_index])
    return pd.DataFrame(matched_universities).reset_index(drop=True)

# Apply the matching process
df_universities_matched = match_jobs_to_universities(similarity_matrix, df_jobs, df_universities)

# Concatenate the matched university data to df_jobs
df_jobs_with_universities = pd.concat([df_jobs.reset_index(drop=True), df_universities_matched.reset_index(drop=True)], axis=1)

# %%
similarity_matrix.max()
# Out:
# np.float64(0.789967634429278)

# %%
df_jobs_with_universities
# Out:
#                 Job Id     Experience Qualifications Salary Range    location  \
# 0     1089843540111562  5 to 15 Years         M.Tech    $59K-$99K     Douglas
# 1      398454096642776  2 to 12 Years            BCA   $56K-$116K    Ashgabat
# 2      481640072963533  0 to 12 Years            PhD   $61K-$104K       Macao
# 3      688192671473044  4 to 11 Years            PhD    $65K-$91K  Porto-Novo
# 4      117057806156508  1 to 12 Years            MBA    $64K-$87K    Santiago
# ...                ...            ...            ...          ...         ...
# 8074  1003521221117999   4 to 9 Years            MCA   $65K-$118K     Nairobi
# 8075  2303241016029011  1 to 14 Years         M.Tech    $59K-$97K      Majuro
# 8076   662454142875177  1 to 14 Years          B.Com    $63K-$82K   Kingstown
# 8077  2594337392461923  1 to 10 Years            MBA    $60K-$99K     Jakarta
# 8078   631689781877458  1 to 10 Years            MCA    $56K-$84K   Bucharest
#
#                              Country  latitude  longitude  Work Type  \
# 0                        Isle of Man   54.2361    -4.5481     Intern
# 1                       Turkmenistan   38.9697    59.5563     Intern
# 2                   Macao SAR, China   22.1987   113.5439  Temporary
# 3                              Benin    9.3077     2.3158  Full-Time
# 4                              Chile  -35.6751   -71.5429     Intern
# ...                              ...       ...        ...        ...
# 8074                           Kenya   -1.2864    36.8172  Temporary
# 8075                Marshall Islands    7.1315   171.1845  Full-Time
# 8076  St. Vincent and the Grenadines   12.9843   -61.2872   Contract
# 8077                       Indonesia   -0.7893   113.9213  Part-Time
# 8078                         Romania   45.9432    24.9668  Temporary
#
#       Company Size  ... tution_2_money tution_2_type  \
# 0            26801  ...            NaN           NaN
# 1           100340  ...         6344.0      National
# 2            84525  ...            NaN           NaN
# 3           129896  ...        31680.0      National
# 4            53944  ...            NaN           NaN
# ...            ...  ...            ...           ...
# 8074         48819  ...        25000.0      National
# 8075        115877  ...        46604.0      National
# 8076         46282  ...          897.0      National
# 8077        129532  ...            NaN           NaN
# 8078         15101  ...            NaN           NaN
#
#      tuition_price_specification             start_date ielts_score  \
# 0                            NaN    2017-11-13 00:00:00         6.5
# 1                 Tuition (Year)    2018-02-01 00:00:00         6.5
# 2                            NaN                    NaN         6.0
# 3                 Tuition (Year)    2018-06-24 00:00:00         6.5
# 4                 Tuition (Year)    2018-02-01 00:00:00         6.5
# ...                          ...                    ...         ...
# 8074              Tuition (Year)    2018-02-27 00:00:00         6.5
# 8075    Tuition (Full programme)    2018-10-31 00:00:00         6.5
# 8076    Tuition (Full programme)    2018-02-03 00:00:00         NaN
# 8077                         NaN    2018-03-01 00:00:00         6.5
# 8078              Tuition (Year)                    NaN         6.5
#
#                                               structure  \
# 0     'community participation' 'social media for or...
# 1     'introduction to teaching and research in the ...
# 2     'introduction to quality health services' 'eva...
# 3     'internet engineering' 'mobile and wireless ne...
# 4     'content marketing and advertising' 'external ...
# ...                                                 ...
# 8074  'advanced consumer behaviour' 'strategic marke...
# 8075  'procurement and logistics' 'supply chain anal...
# 8076  'attendance component a weekend of intensive l...
# 8077  'information security' 'security fundamentals'...
# 8078  'research methods for design' 'fundamental des...
#
#                                            academic_req  \
# 0     <section id="AcademicRequirements"> <h2>Academ...
# 1     <section id="AcademicRequirements"> <h2>Academ...
# 2     <section id="AcademicRequirements"> <h2>Academ...
# 3     <section id="AcademicRequirements"> <h2>Academ...
# 4     <section id="AcademicRequirements"> <h2>Academ...
# ...                                                 ...
# 8074  <section id="AcademicRequirements"> <h2>Academ...
# 8075  <section id="AcademicRequirements"> <h2>Academ...
# 8076  <section id="AcademicRequirements"> <h2>Academ...
# 8077  <section id="AcademicRequirements"> <h2>Academ...
# 8078  <section id="AcademicRequirements"> <h2>Academ...
#
#                                                   facts  \
# 0     ['Starting in   2017-11-13 00:00:00    You can...
# 1     ['Starting in   2018-02-01 00:00:00    You can...
# 2     ['Deadline and start date  Applications are ac...
# 3     ['Starting in   2018-06-24 00:00:00    You can...
# 4     ['Starting in   2018-02-01 00:00:00    You can...
# ...                                                 ...
# 8074  ['Starting in   2018-02-27 00:00:00    You can...
# 8075  ['Starting in   2018-10-31 00:00:00    You can...
# 8076  ['Starting in   2018-02-03 00:00:00    You can...
# 8077  ['Starting in   2018-03-01 00:00:00    You can...
# 8078  ['Deadline and start date  Applications for th...
#
#                                       city  \
# 0     ['Toowoomba', 'Springfield Central']
# 1                             ['Adelaide']
# 2                               ['Hobart']
# 3                            ['Melbourne']
# 4                            ['Melbourne']
# ...                                    ...
# 8074                          ['Brisbane']
# 8075                         ['Melbourne']
# 8076                         ['Melbourne']
# 8077                                   NaN
# 8078                         ['Melbourne']
#
#                                             program_url
# 0     http://www.mastersportal.eu/studies/50229/grad...
# 1     http://www.mastersportal.eu/studies/110288/tea...
# 2     http://www.mastersportal.eu/studies/80343/qual...
# 3     http://www.mastersportal.eu/studies/74170/tele...
# 4     http://www.mastersportal.eu/studies/62913/mark...
# ...                                                 ...
# 8074  http://www.mastersportal.eu/studies/62284/mark...
# 8075  http://www.mastersportal.eu/studies/62906/supp...
# 8076  https://www.preparationcoursesportal.com/studi...
# 8077  http://www.mastersportal.eu/studies/157278/inf...
# 8078  http://www.mastersportal.eu/studies/80698/desi...
#
# [8079 rows x 46 columns]

# %%
df_jobs_with_universities.to_csv(path + 'merged_ds.csv')
